# %%
import pandas as pd
import glob
import os
import json
import numpy as np
from  cycler import cycler
import fastplot
from collections import Counter, defaultdict
from statistics import mode
import statsmodels.stats.proportion
import re

CYCLER_LINESPOINTS=(cycler('color', ['r', 'b', 'g', 'purple', 'c']) +
                    cycler('linestyle', ['-', '--', '-.', ':', (0, (3, 1, 1, 1)) ]) +
                    cycler('marker', ['o', 's', 'v', 'd', '^' ]))

CYCLER_LINES=(cycler('color', ['r', 'b', 'g', 'purple', 'c']) +
                    cycler('linestyle', ['-', '--', '-.', ':', (0, (3, 1, 1, 1)) ]))

PLOT_ARGS = {"style":"latex", "grid":True, "figsize":(4.25,2.5), "rcParams":{'text.latex.preamble': '\\usepackage{libertine}\n\\usepackage{setspace}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}
PLOT_ARGS_LARGE = {"style":"latex", "grid":True, "figsize":(9,2.75), "rcParams":{'text.latex.preamble': '\\usepackage{libertine}\n\\usepackage{setspace}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}

BEFORE_STR = "\\emph{Before-Accept}"
AFTER_STR = "\\emph{After-Accept}"
ADDITIONAL_STR = "\\emph{Additional-Visits}"

TRANSLATE_CATEGORIES = {"Computers Electronics and Technology": "Computers and Technology",
                        "Business and Consumer Services": "Business and Services",
                        "Heavy Industry and Engineering": "Industry and Engineering"}

COUNTRY_TRAD={"it":"Italy", "fr":"France", "de":"Germany", "es":"Spain", "uk":"UK", "us": "US"}

# %matplotlib inline
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_30508\1416070814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
trackers = set( open("trackers-list.txt", "r").read().splitlines() )

similarweb_websites=defaultdict(set)
for c in ["it", "es", "fr", "de", "uk", "us"]:
    similarweb_websites[c] = set(open("similarweb/{}.txt".format(c), "r" ).read().splitlines())

# %%
bad_domains=set("co.uk co.jp co.hu co.il com.au co.ve .co.in com.ec com.pk co.th co.nz com.br com.sg com.sa \
com.do co.za com.hk com.mx com.ly com.ua com.eg com.pe com.tr co.kr com.ng com.pe com.pk co.th \
com.au com.ph com.my com.tw com.ec com.kw co.in co.id com.com com.vn com.bd com.ar \
com.co com.vn org.uk net.gr".split())

def getGood2LD(fqdn):
    if fqdn[-1] == ".":
        fqdn = fqdn[:-1]    
    names = fqdn.split(".")
    if ".".join(names[-2:]) in bad_domains:
        return get3LD(fqdn)
    tln_array = names[-2:]
    tln = ""
    for s in tln_array:
        tln = tln + "." + s
    return tln[1:]

def get3LD(fqdn):
    if fqdn[-1] == ".":
        fqdn = fqdn[:-1]
    names = fqdn.split(".")
    tln_array = names[-3:]
    tln = ""
    for s in tln_array:
        tln = tln + "." + s
    return tln[1:]

# %%
df = pd.read_csv("../data/similarweb-from-it.csv")

# %%
print(df.iloc[0])
# Out:
# directory                                            results_from_it_new
# url                                              http://uni-frankfurt.de
# time                                                   1622297204.924411
# landing_page           https://www.goethe-university-frankfurt.de/en?...
# banner_text                                              Allen zustimmen
# has_scrolled                                                       False
# has_found_banner                                                    True
# cookie_first           [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_click           [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_internal        [{"domain": ".youtube.com", "expires": -1, "si...
# domains_first          ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# domains_click          ["www.uni-frankfurt.de", "www.gstatic.com", "w...
# onload_first                                                        2153
# onload_second                                                       2054
# rum_first                                                    2663.806529
# rum_second                                                      2477.635
# objects_first                                                         35
# objects_second                                                        54
# bytes_first                                                            0
# bytes_second                                                      667704
# byte_index_first                                                     0.0
# object_index_first                                                   0.0
# byte_index_second                                            2793.346215
# object_index_second                                          3158.818685
# Name: 0, dtype: object

# %%
df["sld"] = df["url"].apply(lambda u: getGood2LD(u.split("/")[2] ).strip() ) 
df["tld"] = df["url"].apply(lambda u: get3LD(u.split("/")[2] ).strip()  )

# %%
print(df.iloc[0])
# Out:
# directory                                            results_from_it_new
# url                                              http://uni-frankfurt.de
# time                                                   1622297204.924411
# landing_page           https://www.goethe-university-frankfurt.de/en?...
# banner_text                                              Allen zustimmen
# has_scrolled                                                       False
# has_found_banner                                                    True
# cookie_first           [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_click           [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_internal        [{"domain": ".youtube.com", "expires": -1, "si...
# domains_first          ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# domains_click          ["www.uni-frankfurt.de", "www.gstatic.com", "w...
# onload_first                                                        2153
# onload_second                                                       2054
# rum_first                                                    2663.806529
# rum_second                                                      2477.635
# objects_first                                                         35
# objects_second                                                        54
# bytes_first                                                            0
# bytes_second                                                      667704
# byte_index_first                                                     0.0
# object_index_first                                                   0.0
# byte_index_second                                            2793.346215
# object_index_second                                          3158.818685
# sld                                                     uni-frankfurt.de
# tld                                                     uni-frankfurt.de
# Name: 0, dtype: object

# %%
# adding country to the dataframe
for country in similarweb_websites:
    df[country] = (df.sld.isin(similarweb_websites[country])) | (df.tld.isin(similarweb_websites[country]))

# %%
pd.set_option('display.max_columns', None)
print(df)
# Out:
#                  directory                          url          time  \
# 0      results_from_it_new      http://uni-frankfurt.de  1.622297e+09
# 1      results_from_it_new     http://anwaltauskunft.de  1.621653e+09
# 2      results_from_it_new      http://minuteclinic.com  1.622042e+09
# 3      results_from_it_new               http://cb2.com  1.621730e+09
# 4      results_from_it_new        http://davitamebel.ru  1.621769e+09
# ...                    ...                          ...           ...
# 64928  results_from_it_new        http://finde-offen.de  1.621840e+09
# 64929  results_from_it_new  http://alojadogatopreto.com  1.621645e+09
# 64930  results_from_it_new            http://sluurpy.it  1.622209e+09
# 64931  results_from_it_new             http://vimeo.com  1.622315e+09
# 64932  results_from_it_new      http://zzzquilnatura.it  1.622491e+09
#
#                                             landing_page  \
# 0      https://www.goethe-university-frankfurt.de/en?...
# 1                      https://anwaltauskunft.de/magazin
# 2                 https://www.cvs.com/international.html
# 3                                   https://www.cb2.com/
# 4                                https://davitamebel.ru/
# ...                                                  ...
# 64928                            https://finde-offen.de/
# 64929                       https://gatopreto.com/pt/pt/
# 64930                            https://www.sluurpy.it/
# 64931                                 https://vimeo.com/
# 64932                          https://zzzquilnatura.it/
#
#                   banner_text  has_scrolled  has_found_banner  \
# 0             Allen zustimmen         False              True
# 1                 AKZEPTIEREN         False              True
# 2                         NaN         False             False
# 3                         NaN         False             False
# 4                         NaN         False             False
# ...                       ...           ...               ...
# 64928                     NaN         False             False
# 64929                     NaN         False             False
# 64930                     NaN         False             False
# 64931                     NaN         False             False
# 64932  Accetta tutti i cookie         False              True
#
#                                             cookie_first  \
# 0      [{"domain": "uni-frankfurt.de", "expires": -1,...
# 1      [{"domain": "anwaltauskunft.de", "expires": -1...
# 2      [{"domain": ".cvs.com", "expires": 1622056793....
# 3      [{"domain": ".cb2.com", "expires": 1621733261....
# 4      [{"domain": ".davitamebel.ru", "expires": -1, ...
# ...                                                  ...
# 64928  [{"domain": ".finde-offen.de", "expires": 1621...
# 64929  [{"domain": "gatopreto.com", "expires": -1, "s...
# 64930  [{"domain": "www.sluurpy.it", "expires": -1, "...
# 64931  [{"domain": ".vimeo.com", "expires": 165385103...
# 64932  [{"domain": ".zzzquilnatura.it", "expires": 16...
#
#                                             cookie_click  \
# 0      [{"domain": "uni-frankfurt.de", "expires": -1,...
# 1      [{"domain": "anwaltauskunft.de", "expires": -1...
# 2      [{"domain": ".cvs.com", "expires": 1622056793....
# 3      [{"domain": ".cb2.com", "expires": 1621733261....
# 4      [{"domain": ".davitamebel.ru", "expires": -1, ...
# ...                                                  ...
# 64928  [{"domain": ".finde-offen.de", "expires": 1621...
# 64929  [{"domain": "gatopreto.com", "expires": -1, "s...
# 64930  [{"domain": "www.sluurpy.it", "expires": -1, "...
# 64931  [{"domain": ".vimeo.com", "expires": 165385103...
# 64932  [{"domain": ".zzzquilnatura.it", "expires": 16...
#
#                                          cookie_internal  \
# 0      [{"domain": ".youtube.com", "expires": -1, "si...
# 1      [{"domain": "widgets.outbrain.com", "expires":...
# 2      [{"domain": ".cvs.com", "expires": 1622056793....
# 3      [{"domain": ".cb2.com", "expires": 1621733261....
# 4      [{"domain": ".davitamebel.ru", "expires": -1, ...
# ...                                                  ...
# 64928  [{"domain": ".finde-offen.de", "expires": 1621...
# 64929  [{"domain": "gatopreto.com", "expires": -1, "s...
# 64930  [{"domain": ".google.com", "expires": 16377613...
# 64931  [{"domain": ".vimeo.com", "expires": 193767507...
# 64932  [{"domain": ".zzzquilnatura.it", "expires": 16...
#
#                                            domains_first  \
# 0      ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# 1      ["", "privacy-proxy.usercentrics.eu", "api.use...
# 2      ["www.cvs.com", "mwk9nrke5YUGKRnTcBMlCU1EkQZUm...
# 3                             ["www.cb2.com", "cb2.com"]
# 4      ["www.google.it", "api.carrottrack.io", "xhBQA...
# ...                                                  ...
# 64928          ["ajax.cloudflare.com", "finde-offen.de"]
# 64929  ["bam-cell.nr-data.net", "r1-t.trackedlink.net...
# 64930  ["ajax.googleapis.com", "onesignal.com", "menu...
# 64931  ["vimeo.com", "ct.pinterest.com", "www.google....
# 64932  ["www.google-analytics.com", "cdn.cookielaw.or...
#
#                                            domains_click  onload_first  \
# 0      ["www.uni-frankfurt.de", "www.gstatic.com", "w...          2153
# 1      ["", "privacy-proxy.usercentrics.eu", "api.use...          1787
# 2      ["www.cvs.com", "mwk9nrke5YUGKRnTcBMlCU1EkQZUm...            26
# 3                             ["www.cb2.com", "cb2.com"]            38
# 4      ["www.google.it", "api.carrottrack.io", "stats...          1305
# ...                                                  ...           ...
# 64928          ["ajax.cloudflare.com", "finde-offen.de"]            46
# 64929  ["r1-t.trackedlink.net", "ct.pinterest.com", "...          1029
# 64930  ["www.google-analytics.com", "api.sluurpy.it",...           267
# 64931  ["vimeo.com", "ct.pinterest.com", "www.google....           793
# 64932  ["fonts.gstatic.com", "insight.adsrvr.org", "w...           332
#
#        onload_second    rum_first   rum_second  objects_first  objects_second  \
# 0               2054  2663.806529  2477.635000             35              54
# 1               2277  1041.464886  1045.817298             81              58
# 2                 21    38.000000    38.000000              2               2
# 3                 24    22.000000    19.000000              3               3
# 4               1424   658.260428   649.167032            104             105
# ...              ...          ...          ...            ...             ...
# 64928             42    45.730000    60.004950              3               3
# 64929            924   469.239326   394.984207            361             363
# 64930            297   184.540033   185.280085            107              99
# 64931            990   356.415033   300.548517             53              54
# 64932            612   239.729881   140.340090             36              64
#
#        bytes_first  bytes_second  byte_index_first  object_index_first  \
# 0                0        667704          0.000000            0.000000
# 1          1488951       1328699        842.806885          842.806885
# 2            12381         12381          0.000000            0.000000
# 3              947           947         39.323675           37.090007
# 4           780156        780130        368.355427         1325.032410
# ...            ...           ...               ...                 ...
# 64928            0             0          0.000000            0.000000
# 64929      4216439       4216494       1954.089206         2074.787447
# 64930       775506        397410       1008.296176          842.122070
# 64931       546881        630930        645.089618          652.916626
# 64932      1588218       1913189        463.573975          463.573975
#
#        byte_index_second  object_index_second                   sld  \
# 0            2793.346215          3158.818685      uni-frankfurt.de
# 1             978.905619          1345.439514     anwaltauskunft.de
# 2               0.000000             0.000000      minuteclinic.com
# 3              30.504533            29.007975               cb2.com
# 4             337.869047          1438.938203        davitamebel.ru
# ...                  ...                  ...                   ...
# 64928           0.000000             0.000000        finde-offen.de
# 64929        2067.429115          2340.715464  alojadogatopreto.com
# 64930         602.252450           594.948649            sluurpy.it
# 64931         518.583135           717.556996             vimeo.com
# 64932         202.808652           426.120042      zzzquilnatura.it
#
#                         tld     it     es     fr     de     uk     us
# 0          uni-frankfurt.de  False  False  False   True  False  False
# 1         anwaltauskunft.de  False  False  False   True  False  False
# 2          minuteclinic.com  False  False  False  False  False   True
# 3                   cb2.com  False  False  False  False  False   True
# 4            davitamebel.ru  False  False  False  False  False  False
# ...                     ...    ...    ...    ...    ...    ...    ...
# 64928        finde-offen.de  False  False  False   True  False  False
# 64929  alojadogatopreto.com  False   True  False  False  False  False
# 64930            sluurpy.it   True  False  False  False  False  False
# 64931             vimeo.com   True   True   True   True   True   True
# 64932      zzzquilnatura.it   True  False  False  False  False  False
#
# [64933 rows x 32 columns]

# %%
print(df[df["url"]=="http://uni-frankfurt.de"])
# Out:
#                  directory                      url          time  \
# 0      results_from_it_new  http://uni-frankfurt.de  1.622297e+09
# 14468  results_from_it_new  http://uni-frankfurt.de  1.622297e+09
# 14713  results_from_it_new  http://uni-frankfurt.de  1.622297e+09
# 20239  results_from_it_new  http://uni-frankfurt.de  1.622297e+09
# 38836  results_from_it_new  http://uni-frankfurt.de  1.622297e+09
#
#                                             landing_page      banner_text  \
# 0      https://www.goethe-university-frankfurt.de/en?...  Allen zustimmen
# 14468  https://www.goethe-university-frankfurt.de/en?...  Allen zustimmen
# 14713  https://www.goethe-university-frankfurt.de/en?...  Allen zustimmen
# 20239  https://www.goethe-university-frankfurt.de/en?...  Allen zustimmen
# 38836  https://www.goethe-university-frankfurt.de/en?...  Allen zustimmen
#
#        has_scrolled  has_found_banner  \
# 0             False              True
# 14468         False              True
# 14713         False              True
# 20239         False              True
# 38836         False              True
#
#                                             cookie_first  \
# 0      [{"domain": "uni-frankfurt.de", "expires": -1,...
# 14468  [{"domain": "uni-frankfurt.de", "expires": -1,...
# 14713  [{"domain": "uni-frankfurt.de", "expires": -1,...
# 20239  [{"domain": "uni-frankfurt.de", "expires": -1,...
# 38836  [{"domain": "uni-frankfurt.de", "expires": -1,...
#
#                                             cookie_click  \
# 0      [{"domain": "uni-frankfurt.de", "expires": -1,...
# 14468  [{"domain": "uni-frankfurt.de", "expires": -1,...
# 14713  [{"domain": "uni-frankfurt.de", "expires": -1,...
# 20239  [{"domain": "uni-frankfurt.de", "expires": -1,...
# 38836  [{"domain": "uni-frankfurt.de", "expires": -1,...
#
#                                          cookie_internal  \
# 0      [{"domain": ".youtube.com", "expires": -1, "si...
# 14468  [{"domain": ".youtube.com", "expires": -1, "si...
# 14713  [{"domain": ".youtube.com", "expires": -1, "si...
# 20239  [{"domain": "www.goethe-university-frankfurt.d...
# 38836  [{"domain": ".youtube.com", "expires": -1, "si...
#
#                                            domains_first  \
# 0      ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# 14468  ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# 14713  ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# 20239  ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# 38836  ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
#
#                                            domains_click  onload_first  \
# 0      ["www.uni-frankfurt.de", "www.gstatic.com", "w...          2153
# 14468  ["www.uni-frankfurt.de", "www.gstatic.com", "w...          2294
# 14713  ["www.uni-frankfurt.de", "www.gstatic.com", "w...          2067
# 20239  ["www.uni-frankfurt.de", "www.gstatic.com", "w...          2386
# 38836  ["www.uni-frankfurt.de", "www.gstatic.com", "w...          2496
#
#        onload_second    rum_first   rum_second  objects_first  objects_second  \
# 0               2054  2663.806529  2477.635000             35              54
# 14468           2225  2942.980051  2598.600149             35              54
# 14713           2388  2597.394943  2533.742531             35              54
# 20239           2396  2820.834875  2980.347655             35              54
# 38836           2266  3060.669899  2652.925082             35              54
#
#        bytes_first  bytes_second  byte_index_first  object_index_first  \
# 0                0        667704               0.0                 0.0
# 14468            0        667704               0.0                 0.0
# 14713            0        667704               0.0                 0.0
# 20239            0        667704               0.0                 0.0
# 38836            0        667704               0.0                 0.0
#
#        byte_index_second  object_index_second               sld  \
# 0            2793.346215          3158.818685  uni-frankfurt.de
# 14468        2967.208807          3329.405355  uni-frankfurt.de
# 14713        3119.438642          3489.225667  uni-frankfurt.de
# 20239        3127.918168          3488.335693  uni-frankfurt.de
# 38836        3024.973998          3384.738688  uni-frankfurt.de
#
#                     tld     it     es     fr    de     uk     us
# 0      uni-frankfurt.de  False  False  False  True  False  False
# 14468  uni-frankfurt.de  False  False  False  True  False  False
# 14713  uni-frankfurt.de  False  False  False  True  False  False
# 20239  uni-frankfurt.de  False  False  False  True  False  False
# 38836  uni-frankfurt.de  False  False  False  True  False  False

# %%
similarweb_csv = pd.read_csv("similarweb/similarweb.csv")

# %%
print(similarweb_csv)
# Out:
#       country  category           website
# 0          it       ALL        google.com
# 1          it       ALL      facebook.com
# 2          it       ALL       youtube.com
# 3          it       ALL         google.it
# 4          it       ALL         amazon.it
# ...       ...       ...               ...
# 23795      ru  Vehicles         ffclub.ru
# 23796      ru  Vehicles  oh-wow-shop.info
# 23797      ru  Vehicles      masmotors.ru
# 23798      ru  Vehicles     cardinator.ru
# 23799      ru  Vehicles        5koleso.ru
#
# [23800 rows x 3 columns]

# %%
# adding categories to the dataframe
similarweb_csv["category"] = similarweb_csv["category"].apply(lambda s: TRANSLATE_CATEGORIES[s] if s in TRANSLATE_CATEGORIES else s)
categories = defaultdict(set)

for row in similarweb_csv.itertuples():
    if row.category != "ALL" and row.country in {"it", "es", "fr", "de", "uk"} :
        categories[row.category].add(row.website)
        
for category in categories:
    df[category] = (df.sld.isin(categories[category])) | (df.tld.isin(categories[category]))

# %%
print(df.iloc[0])
# Out:
# directory                                                 results_from_it_new
# url                                                   http://uni-frankfurt.de
# time                                                        1622297204.924411
# landing_page                https://www.goethe-university-frankfurt.de/en?...
# banner_text                                                   Allen zustimmen
# has_scrolled                                                            False
# has_found_banner                                                         True
# cookie_first                [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_click                [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_internal             [{"domain": ".youtube.com", "expires": -1, "si...
# domains_first               ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# domains_click               ["www.uni-frankfurt.de", "www.gstatic.com", "w...
# onload_first                                                             2153
# onload_second                                                            2054
# rum_first                                                         2663.806529
# rum_second                                                           2477.635
# objects_first                                                              35
# objects_second                                                             54
# bytes_first                                                                 0
# bytes_second                                                           667704
# byte_index_first                                                          0.0
# object_index_first                                                        0.0
# byte_index_second                                                 2793.346215
# object_index_second                                               3158.818685
# sld                                                          uni-frankfurt.de
# tld                                                          uni-frankfurt.de
# it                                                                      False
# es                                                                      False
# fr                                                                      False
# de                                                                       True
# uk                                                                      False
# us                                                                      False
# Adult                                                                   False
# Arts and Entertainment                                                  False
# Business and Services                                                   False
# Community and Society                                                   False
# Computers and Technology                                                False
# E-commerce and Shopping                                                 False
# Finance                                                                 False
# Food and Drink                                                          False
# Gambling                                                                False
# Games                                                                   False
# Health                                                                  False
# Industry and Engineering                                                False
# Hobbies and Leisure                                                     False
# Home and Garden                                                         False
# Jobs and Career                                                         False
# Law and Government                                                      False
# Lifestyle                                                               False
# News and Media                                                          False
# Pets and Animals                                                        False
# Reference Materials                                                     False
# Science and Education                                                    True
# Sports                                                                  False
# Travel and Tourism                                                      False
# Vehicles                                                                False
# Name: 0, dtype: object

# %%
# getting the trackers for before, after and internal banner.
# Note that only checking the tracker that is in the tracker list and not expried
def get_trackers(s):
    d = json.loads(s)
    this_trackers = set()
    for c in d:
        if (c["domain"] in trackers or getGood2LD(c["domain"]) in trackers or get3LD(c["domain"]) in trackers) and c["expires"] > 0:
            this_trackers.add(getGood2LD(c["domain"]))
    return list(this_trackers)

df["trackers_first"] = df["cookie_first"].apply(get_trackers)
df["trackers_click"] = df["cookie_click"].apply(get_trackers)
df["trackers_internal"] = df["cookie_internal"].apply(get_trackers)

# %%
print(df.iloc[0])
# Out:
# directory                                                 results_from_it_new
# url                                                   http://uni-frankfurt.de
# time                                                        1622297204.924411
# landing_page                https://www.goethe-university-frankfurt.de/en?...
# banner_text                                                   Allen zustimmen
# has_scrolled                                                            False
# has_found_banner                                                         True
# cookie_first                [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_click                [{"domain": "uni-frankfurt.de", "expires": -1,...
# cookie_internal             [{"domain": ".youtube.com", "expires": -1, "si...
# domains_first               ["www.uni-frankfurt.de", "uni-frankfurt.de", "...
# domains_click               ["www.uni-frankfurt.de", "www.gstatic.com", "w...
# onload_first                                                             2153
# onload_second                                                            2054
# rum_first                                                         2663.806529
# rum_second                                                           2477.635
# objects_first                                                              35
# objects_second                                                             54
# bytes_first                                                                 0
# bytes_second                                                           667704
# byte_index_first                                                          0.0
# object_index_first                                                        0.0
# byte_index_second                                                 2793.346215
# object_index_second                                               3158.818685
# sld                                                          uni-frankfurt.de
# tld                                                          uni-frankfurt.de
# it                                                                      False
# es                                                                      False
# fr                                                                      False
# de                                                                       True
# uk                                                                      False
# us                                                                      False
# Adult                                                                   False
# Arts and Entertainment                                                  False
# Business and Services                                                   False
# Community and Society                                                   False
# Computers and Technology                                                False
# E-commerce and Shopping                                                 False
# Finance                                                                 False
# Food and Drink                                                          False
# Gambling                                                                False
# Games                                                                   False
# Health                                                                  False
# Industry and Engineering                                                False
# Hobbies and Leisure                                                     False
# Home and Garden                                                         False
# Jobs and Career                                                         False
# Law and Government                                                      False
# Lifestyle                                                               False
# News and Media                                                          False
# Pets and Animals                                                        False
# Reference Materials                                                     False
# Science and Education                                                    True
# Sports                                                                  False
# Travel and Tourism                                                      False
# Vehicles                                                                False
# trackers_first                                                             []
# trackers_click                                              [doubleclick.net]
# trackers_internal                                           [doubleclick.net]
# Name: 0, dtype: object

# %%
# group the websites by second level domain: total of 13159 websites.
def website_stats(this_df):
    num = len(this_df.index)
    trackers_first = set()
    trackers_click = set()
    trackers_internal = set()
    
    trackers_first_all = set(this_df.iloc[0].trackers_first)
    trackers_click_all = set(this_df.iloc[0].trackers_click)
    trackers_internal_all = set(this_df.iloc[0].trackers_internal)
    trackers_details = []

    has_found_banner = False
    
    tp_first = set()
    tp_click = set()
    
    countries = { c:False for c in similarweb_websites.keys()}
    cats = { c:False for c in categories.keys()}
    #+ list(similarweb_websites.keys()) + list(categories.keys())
    
    
    for i, row in this_df.iterrows():

        trackers_first |= set(row.trackers_first)
        trackers_click |= set(row.trackers_click)
        trackers_internal |= set(row.trackers_internal)
        
        trackers_first_all &= set(row.trackers_first)
        trackers_click_all &= set(row.trackers_click)
        trackers_internal_all &= set(row.trackers_internal)
        
        trackers_details.append(set(row.trackers_click))
        
        tp_first |= set([ getGood2LD(d) for d in json.loads(row.domains_first) if d != ""] )
        tp_click |= set([ getGood2LD(d) for d in json.loads(row.domains_click) if d != ""])      
        
        for c in list(similarweb_websites.keys()):
            countries[c] |= row[c]

        for c in list(categories.keys()):
            cats[c] |= row[c]
            
        if row.has_found_banner:
            has_found_banner=True
        
    trackers_only_click = trackers_click - trackers_first
    
    trackers_acc = set()
    trackers_incremental = []
    for s in trackers_details:
        trackers_acc |= s
        trackers_incremental.append(len(trackers_acc))
    
    return pd.Series({"count": num,
                      "trackers_first": trackers_first,
                      "trackers_click": trackers_click,
                      "trackers_only_click": trackers_only_click,
                      "trackers_internal": trackers_internal,
                      
                      "trackers_first_all": trackers_first_all,
                      "trackers_click_all": trackers_click_all,
                      "trackers_internal_all": trackers_internal_all,
                      
                      "trackers_incremental_nb": trackers_incremental,
                    
                      "tp_first": tp_first,
                      "tp_click": tp_click,
                      "has_found_banner": has_found_banner,
                      "onload_first": this_df["onload_first"].median(),
                      "onload_second": this_df["onload_second"].median(),
                      "rum_first": this_df["rum_first"].mean(),
                      "rum_second": this_df["rum_second"].mean(),
                      "objects_first": this_df["objects_first"].mean(),
                      "objects_second": this_df["objects_second"].mean(),
                      "bytes_first": this_df["bytes_first"].median(),
                      "bytes_second": this_df["bytes_second"].median(),
                      "byte_index_first": this_df["byte_index_first"].mean(),
                      "object_index_first": this_df["object_index_first"].mean(),
                      "byte_index_second": this_df["byte_index_second"].mean(),
                      "object_index_second": this_df["object_index_second"].mean(),
                      **countries, **cats
                     })
# grouped = df.groupby(["sld"]).apply(website_stats).reset_index()
grouped = df.groupby(["sld"]).apply(website_stats,include_groups=False).reset_index()
grouped
# Out:
#                     sld  count  \
# 0              003ms.ru      5
# 1          009.xn--p1ai      2
# 2             01net.com      2
# 3       01streaming.net      5
# 4          03online.com      4
# ...                 ...    ...
# 13154        zweisam.de      5
# 13155         zwinkr.de      5
# 13156         zwinkr.me      5
# 13157           zzap.ru      5
# 13158  zzzquilnatura.it      5
#
#                                           trackers_first  \
# 0                                  {yadro.ru, yandex.ru}
# 1                                            {yandex.ru}
# 2                 {fwmrm.net, dailymotion.com, xiti.com}
# 3                                                     {}
# 4      {addthis.com, pubmatic.com, aidata.io, digital...
# ...                                                  ...
# 13154                                      {iesnare.com}
# 13155                                                 {}
# 13156                                                 {}
# 13157                                        {yandex.ru}
# 13158                                                 {}
#
#                                           trackers_click  \
# 0                                  {yadro.ru, yandex.ru}
# 1                                            {yandex.ru}
# 2      {dailymotion.com, mathtag.com, rlcdn.com, doub...
# 3                                                     {}
# 4      {addthis.com, pubmatic.com, aidata.io, digital...
# ...                                                  ...
# 13154                                      {iesnare.com}
# 13155                                                 {}
# 13156                                                 {}
# 13157                                        {yandex.ru}
# 13158  {doubleclick.net, agkn.com, tapad.com, adsrvr....
#
#                                      trackers_only_click  \
# 0                                                     {}
# 1                                                     {}
# 2      {tradedoubler.com, aliexpress.com, stickyadstv...
# 3                                                     {}
# 4                                                     {}
# ...                                                  ...
# 13154                                                 {}
# 13155                                                 {}
# 13156                                                 {}
# 13157                                                 {}
# 13158  {tapad.com, adsrvr.org, mathtag.com, doublecli...
#
#                                        trackers_internal  \
# 0                                  {yadro.ru, yandex.ru}
# 1                                            {yandex.ru}
# 2      {dmxleo.com, giphy.com, smartclip.net, aniview...
# 3                                                     {}
# 4      {addthis.com, tns-counter.ru, upravel.com, qua...
# ...                                                  ...
# 13154                                      {iesnare.com}
# 13155                                                 {}
# 13156                                                 {}
# 13157  {aidata.io, digitaltarget.ru, semantiqo.com, t...
# 13158  {flashtalking.com, doubleclick.net, agkn.com, ...
#
#                                       trackers_first_all  \
# 0                                  {yadro.ru, yandex.ru}
# 1                                            {yandex.ru}
# 2                 {fwmrm.net, dailymotion.com, xiti.com}
# 3                                                     {}
# 4      {yandex.ru, doubleclick.net, 1dmp.io, weborama...
# ...                                                  ...
# 13154                                      {iesnare.com}
# 13155                                                 {}
# 13156                                                 {}
# 13157                                        {yandex.ru}
# 13158                                                 {}
#
#                                       trackers_click_all  \
# 0                                  {yadro.ru, yandex.ru}
# 1                                            {yandex.ru}
# 2      {dailymotion.com, mathtag.com, rlcdn.com, doub...
# 3                                                     {}
# 4      {quantserve.com, yandex.ru, doubleclick.net, 1...
# ...                                                  ...
# 13154                                      {iesnare.com}
# 13155                                                 {}
# 13156                                                 {}
# 13157                                        {yandex.ru}
# 13158  {doubleclick.net, agkn.com, tapad.com, adsrvr....
#
#                                    trackers_internal_all  \
# 0                                  {yadro.ru, yandex.ru}
# 1                                            {yandex.ru}
# 2      {dmxleo.com, aniview.com, dailymotion.com, tri...
# 3                                                     {}
# 4      {quantserve.com, yandex.ru, rlcdn.com, addthis...
# ...                                                  ...
# 13154                                      {iesnare.com}
# 13155                                                 {}
# 13156                                                 {}
# 13157                                        {yandex.ru}
# 13158  {flashtalking.com, doubleclick.net, agkn.com, ...
#
#       trackers_incremental_nb  \
# 0             [2, 2, 2, 2, 2]
# 1                      [1, 1]
# 2                    [20, 30]
# 3             [0, 0, 0, 0, 0]
# 4            [16, 17, 18, 19]
# ...                       ...
# 13154         [1, 1, 1, 1, 1]
# 13155         [0, 0, 0, 0, 0]
# 13156         [0, 0, 0, 0, 0]
# 13157         [1, 1, 1, 1, 1]
# 13158         [5, 5, 5, 5, 5]
#
#                                                 tp_first  \
# 0      {googleoptimize.com, 003ms.ru, yandex.ru, doub...
# 1      {009.am, gstatic.com, facebook.com, 0eMcdRCXsE...
# 2      {dmxleo.com, privacy-center.org, accengage.net...
# 3      {freegeoip.app, facebook.com, google-analytics...
# 4      {aZVPoRhJ3CTr6qMC, addthis.com, googlesyndicat...
# ...                                                  ...
# 13154  {onetrust.com, akamaihd.net, cookielaw.org, il...
# 13155  {mxpnl.com, zwinkr.de, facebook.net, zwinkr.me...
# 13156  {mxpnl.com, facebook.net, zwinkr.me, googletag...
# 13157  {yandex.ru, facebook.net, cloudflareinsights.c...
# 13158  {ctfassets.net, cookielaw.org, gstatic.com, go...
#
#                                                 tp_click  has_found_banner  \
# 0      {googleoptimize.com, 003ms.ru, yandex.ru, doub...             False
# 1      {yandex.ru, 009.xn--p1ai, googleapis.com, gsta...             False
# 2      {dmxleo.com, jsdelivr.net, accengage.net, goog...              True
# 3      {freegeoip.app, facebook.com, google-analytics...             False
# 4      {gstatic.com, googlesyndication.com, 03online....             False
# ...                                                  ...               ...
# 13154  {akamaihd.net, cookielaw.org, ilius.net, gstat...              True
# 13155  {mxpnl.com, zwinkr.de, facebook.net, zwinkr.me...              True
# 13156  {mxpnl.com, facebook.net, zwinkr.me, googletag...              True
# 13157  {yandex.ru, facebook.net, cloudflareinsights.c...             False
# 13158  {facebook.com, tapad.com, zzzquilnatura.it, go...              True
#
#        onload_first  onload_second      rum_first    rum_second  \
# 0            4021.0       130480.0   97751.105300    812.935199
# 1            1335.0          470.5  161435.840417    232.349873
# 2            1463.5        68832.0   81255.235156    865.271356
# 3             745.0          778.0     290.557051    252.389002
# 4           65490.0         1339.5   16333.871245  16341.071308
# ...             ...            ...            ...           ...
# 13154         711.0          716.0     296.846663    221.742508
# 13155         514.0          493.0     630.681288    544.988633
# 13156         370.0          343.0     346.953374    304.534810
# 13157         698.0          697.0     441.290339    394.639198
# 13158         347.0          634.0     236.329937    163.691950
#
#        objects_first  objects_second  bytes_first  bytes_second  \
# 0              227.8           224.8    1049122.0     1051994.0
# 1               56.0            50.0     197652.0      197277.0
# 2              169.5           354.0    2265976.0     3073923.0
# 3               22.0            21.0     465162.0      465162.0
# 4               87.0            62.0    1357535.0      695826.0
# ...              ...             ...          ...           ...
# 13154           45.0            45.0     251092.0      349272.0
# 13155           29.0            29.0    1033699.0     1033699.0
# 13156           27.4            29.0      97653.0       99431.0
# 13157           37.0            35.0     229660.0      229574.0
# 13158           36.0            64.0    1588219.0     1913191.0
#
#        byte_index_first  object_index_first  byte_index_second  \
# 0           1610.961488        10471.295010        1186.156820
# 1            814.830817         1820.271172        1202.054934
# 2           3452.603580         3031.065286       64439.949007
# 3            225.628630         1543.965857         204.701032
# 4          37558.196993        39019.067185       16959.414579
# ...                 ...                 ...                ...
# 13154        669.981222          661.751392         560.853539
# 13155          0.000000            0.000000           0.000000
# 13156          0.000000            0.000000         258.731592
# 13157        513.861108          711.658659         662.688100
# 13158        492.355615          492.355615         236.778124
#
#        object_index_second     it     es     fr     de     uk     us  Adult  \
# 0             21449.740093  False  False  False  False  False  False  False
# 1               960.476359  False  False  False  False  False  False  False
# 2             57925.091038  False  False   True  False  False  False  False
# 3              1569.040198  False  False   True  False  False  False  False
# 4             16977.239290  False  False  False  False  False  False  False
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 13154           659.287450  False  False  False   True  False  False  False
# 13155             0.000000  False  False  False   True  False  False  False
# 13156           258.731592  False  False  False   True  False  False  False
# 13157          1043.581274  False  False  False  False  False  False  False
# 13158           464.724750   True  False  False  False  False  False  False
#
#        Arts and Entertainment  Business and Services  Community and Society  \
# 0                       False                  False                  False
# 1                       False                  False                  False
# 2                       False                  False                  False
# 3                        True                  False                  False
# 4                       False                  False                  False
# ...                       ...                    ...                    ...
# 13154                   False                  False                   True
# 13155                   False                  False                   True
# 13156                   False                  False                  False
# 13157                   False                  False                  False
# 13158                   False                  False                  False
#
#        Computers and Technology  E-commerce and Shopping  Finance  \
# 0                         False                    False    False
# 1                         False                    False    False
# 2                          True                    False    False
# 3                         False                    False    False
# 4                         False                    False    False
# ...                         ...                      ...      ...
# 13154                     False                    False    False
# 13155                     False                    False    False
# 13156                     False                    False    False
# 13157                     False                    False    False
# 13158                     False                    False    False
#
#        Food and Drink  Gambling  Games  Health  Industry and Engineering  \
# 0               False     False  False   False                     False
# 1               False     False  False   False                     False
# 2               False     False  False   False                     False
# 3               False     False  False   False                     False
# 4               False     False  False   False                     False
# ...               ...       ...    ...     ...                       ...
# 13154           False     False  False   False                     False
# 13155           False     False  False   False                     False
# 13156           False      True  False   False                     False
# 13157           False     False  False   False                     False
# 13158            True     False  False   False                     False
#
#        Hobbies and Leisure  Home and Garden  Jobs and Career  \
# 0                    False            False            False
# 1                    False            False            False
# 2                    False            False            False
# 3                    False            False            False
# 4                    False            False            False
# ...                    ...              ...              ...
# 13154                False            False            False
# 13155                False            False            False
# 13156                False            False            False
# 13157                False            False            False
# 13158                False            False            False
#
#        Law and Government  Lifestyle  News and Media  Pets and Animals  \
# 0                   False      False           False             False
# 1                   False      False           False             False
# 2                   False      False           False             False
# 3                   False      False           False             False
# 4                   False      False           False             False
# ...                   ...        ...             ...               ...
# 13154               False      False           False             False
# 13155               False      False           False             False
# 13156               False      False           False             False
# 13157               False      False           False             False
# 13158               False      False           False             False
#
#        Reference Materials  Science and Education  Sports  Travel and Tourism  \
# 0                    False                  False   False               False
# 1                    False                  False   False               False
# 2                    False                  False   False               False
# 3                    False                  False   False               False
# 4                    False                  False   False               False
# ...                    ...                    ...     ...                 ...
# 13154                False                  False   False               False
# 13155                False                  False   False               False
# 13156                False                  False   False               False
# 13157                False                  False   False               False
# 13158                False                  False   False               False
#
#        Vehicles
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 13154     False
# 13155     False
# 13156     False
# 13157     False
# 13158     False
#
# [13159 rows x 55 columns]

# %%
print([ele for ele in grouped[grouped['sld'] == 'uni-frankfurt.de']['tp_first']])
# Out:
# [{'uni-frankfurt.de', 'goethe-university-frankfurt.de', 'VC1p42mNgYGBmgGAZBkYGEMgB8hjBfBaGACAtAIQgeQWGBQpcCvoK8ap'}]

# %%
print(grouped[grouped['sld'] == 'uni-frankfurt.de'])

# %%
print([grouped[grouped['sld'] == 'uni-frankfurt.de'][ele] for ele in grouped[grouped['sld'] == 'uni-frankfurt.de']])
# Out:
# [11977    uni-frankfurt.de
# Name: sld, dtype: object, 11977    5
# Name: count, dtype: int64, 11977    {}
# Name: trackers_first, dtype: object, 11977    {doubleclick.net}
# Name: trackers_click, dtype: object, 11977    {doubleclick.net}
# Name: trackers_only_click, dtype: object, 11977    {doubleclick.net, adition.com}
# Name: trackers_internal, dtype: object, 11977    {}
# Name: trackers_first_all, dtype: object, 11977    {doubleclick.net}
# Name: trackers_click_all, dtype: object, 11977    {doubleclick.net}
# Name: trackers_internal_all, dtype: object, 11977    [1, 1, 1, 1, 1]
# Name: trackers_incremental_nb, dtype: object, 11977    {uni-frankfurt.de, goethe-university-frankfurt...
# Name: tp_first, dtype: object, 11977    {T, ytimg.com, gstatic.com, ggpht.com, youtube...
# Name: tp_click, dtype: object, 11977    True
# Name: has_found_banner, dtype: bool, 11977    2294.0
# Name: onload_first, dtype: float64, 11977    2266.0
# Name: onload_second, dtype: float64, 11977    2817.137259
# Name: rum_first, dtype: float64, 11977    2648.650084
# Name: rum_second, dtype: float64, 11977    35.0
# Name: objects_first, dtype: float64, 11977    54.0
# Name: objects_second, dtype: float64, 11977    0.0
# Name: bytes_first, dtype: float64, 11977    667704.0
# Name: bytes_second, dtype: float64, 11977    0.0
# Name: byte_index_first, dtype: float64, 11977    0.0
# Name: object_index_first, dtype: float64, 11977    3006.577166
# Name: byte_index_second, dtype: float64, 11977    3370.104818
# Name: object_index_second, dtype: float64, 11977    False
# Name: it, dtype: bool, 11977    False
# Name: es, dtype: bool, 11977    False
# Name: fr, dtype: bool, 11977    True
# Name: de, dtype: bool, 11977    False
# Name: uk, dtype: bool, 11977    False
# Name: us, dtype: bool, 11977    False
# Name: Adult, dtype: bool, 11977    False
# Name: Arts and Entertainment, dtype: bool, 11977    False
# Name: Business and Services, dtype: bool, 11977    False
# Name: Community and Society, dtype: bool, 11977    False
# Name: Computers and Technology, dtype: bool, 11977    False
# Name: E-commerce and Shopping, dtype: bool, 11977    False
# Name: Finance, dtype: bool, 11977    False
# Name: Food and Drink, dtype: bool, 11977    False
# Name: Gambling, dtype: bool, 11977    False
# Name: Games, dtype: bool, 11977    False
# Name: Health, dtype: bool, 11977    False
# Name: Industry and Engineering, dtype: bool, 11977    False
# Name: Hobbies and Leisure, dtype: bool, 11977    False
# Name: Home and Garden, dtype: bool, 11977    False
# Name: Jobs and Career, dtype: bool, 11977    False
# Name: Law and Government, dtype: bool, 11977    False
# Name: Lifestyle, dtype: bool, 11977    False
# Name: News and Media, dtype: bool, 11977    False
# Name: Pets and Animals, dtype: bool, 11977    False
# Name: Reference Materials, dtype: bool, 11977    True
# Name: Science and Education, dtype: bool, 11977    False
# Name: Sports, dtype: bool, 11977    False
# Name: Travel and Tourism, dtype: bool, 11977    False
# Name: Vehicles, dtype: bool]

# %%
PLOT_ARGS_SMALL = {"style":"latex", "grid":True, "figsize":(2,2.25), "rcParams":{'text.latex.preamble': r'\usepackage{libertine}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}

W=100
for c in ["fr", "de", "it", "es", "uk", "us"]:

    plot_data = grouped [ grouped[[c]].any(axis=1) ].copy()
    missing = 0#10542 - len(plot_data.index)
    plot_data["trackers_first_nb"] = plot_data["trackers_first"].apply(len)
    plot_data["trackers_click_nb"] = plot_data["trackers_click"].apply(len)
    plot_data = plot_data[["trackers_first_nb", "trackers_click_nb"]]

    # plot_data = plot_data.append( [{"trackers_first_nb":0, "trackers_click_nb":0}]*missing ).sample(frac=1)
    plot_data = plot_data._append( [{"trackers_first_nb":0, "trackers_click_nb":0}]*missing ).sample(frac=1)

    plot_data= plot_data.sort_values(by="trackers_first_nb", ascending=False).reset_index()
    plot_list = [(BEFORE_STR,   (np.arange(len(plot_data["trackers_first_nb"].values ) ) +1 ,   plot_data["trackers_first_nb"].values  ) ),
                 (AFTER_STR, (np.arange(len(plot_data["trackers_click_nb"].values) ) +1 , plot_data["trackers_click_nb"].values ) ),
                ]

    avg = (np.arange(len(plot_data["trackers_click_nb"].values) ) +1 , plot_data["trackers_click_nb"].rolling(W).mean().values )
        
    CYCLER_LINESANDPOINTS=(cycler('color', ['r', 'b', 'b', 'b', 'c']) +
                        cycler('linestyle', ['-', '', '-.', '-', (0, (3, 1, 1, 1)) ]) +
                        cycler('marker', ['', 's', '', '', '^' ]))

    has_legend = c == "fr"
    ylabel = 'Tracker Number' if has_legend else None
    yticks = ([0,20,40,60,80],None) if has_legend else ([0,20,40,60,80],["","","","",""])
    #xlabel = "{}\\\\Websites".format(COUNTRY_TRAD[c]) if c == "it" else "{}".format(COUNTRY_TRAD[c])
    xlabel = "{}".format(COUNTRY_TRAD[c])
    
    plot = fastplot.plot( plot_list ,None, 
                   mode='line_multi', ylabel = ylabel,
                   legend = has_legend, legend_loc='upper right', legend_ncol=1, legend_fontsize=12, legend_alpha=0.5,
                     xlabel = "Websites", linewidth=2, fontsize=12,
                   xlim = (-100, 2500), cycler = CYCLER_LINESANDPOINTS, plot_args = {"markersize": 1},
                         xticks = ([0,1000,2000],None), yticks = yticks,
                   ylim = (-5,80), **PLOT_ARGS_SMALL)

    if has_legend:
        # plot.gca().get_legend().legendHandles[1]._legmarker.set_markersize(5)
        plot.gca().get_legend().legend_handles[1].set_markersize(5)
    plot.plot(plot_list[0][1][0], plot_list[0][1][1], "-", color="red", marker=None, markersize=0)
    plot.title(xlabel)
    
    plot.plot(avg[0], avg[1])
    
    plot.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9) 
    plot.savefig("plots/cookieaccept_overall_tracker_nb_{}.pdf".format(c), bbox_inches = "tight")
    
    plot.show()

# %%
plot_data = []

for country in similarweb_websites.keys():
    this_grouped = grouped[grouped[country] == True]
    tot = len(this_grouped.index)
    tracker_first = len(this_grouped[this_grouped["trackers_first"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_click = len(this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_internal = len(this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) > 0 ) ].index)
    plot_data.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR: tracker_first/tot*100,
                      AFTER_STR: tracker_click/tot*100,
                      ADDITIONAL_STR: tracker_internal/tot*100,
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="country")
plot_df.index = plot_df["country"]
del plot_df["country"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)
    
plot = fastplot.plot( plot_df ,None, 
               mode='bars_multi', ylabel = 'Websites With Trackers [\\%]',
               legend = True, legend_loc='upper left', legend_ncol=3, legend_fontsize="small",
               grid_axis="y",
               ylim = (0,100), **THIS_PLOT_ARGS)


for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):len(plot_df)*2]+ [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")
    
for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")

#plot.gca().patches[5].set_hatch("XXXX")
#plot.gca().patches[11].set_hatch("++++")
#plot.gca().patches[17].set_hatch("....")

for i, country in enumerate(["fr", "de", "it", "es", "uk", "us"]):
    this_grouped = grouped[grouped[country] == True]
    n = round(len(this_grouped[this_grouped["has_found_banner"]].index)/len(this_grouped.index)*100,1)
    plot.text(i, 105, "{}\\%".format(n), ha="center", bbox = dict(boxstyle='square,pad=0', color="white"))
    
plot.text(2.5, 115, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

plot.subplots_adjust(left=0.125, bottom=0.1, right=0.95, top=0.85) 

# err = plot_df.applymap(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
err = plot_df.map(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
for i, tup in enumerate(err.itertuples()):
    plot.gca().plot( (i-0.2,i-0.2), (tup[1]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (tup[2]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (tup[3]), linestyle="-", color="black" )
    
plot.savefig("plots/cookieaccept_websites_with_trackers.pdf", bbox_inches = "tight")
plot.show()
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_3528\1138702745.py:53: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plot.text(2.5, 115, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

# %%
plot_data = []

for country in similarweb_websites.keys():
    this_grouped = grouped[grouped[country] == True]
    tot = len(this_grouped.index)
    tot_wo = len(this_grouped[this_grouped["has_found_banner"]==False].index)
    tot_w = len(this_grouped[this_grouped["has_found_banner"]==True].index)
    tracker_first_wo = len(this_grouped[ (this_grouped["trackers_first"].apply(lambda s: len(s) > 0 )) & ( this_grouped["has_found_banner"]==False) ].index)
    tracker_click_wo = len(this_grouped[ (this_grouped["trackers_click"].apply(lambda s: len(s) > 0 )) & ( this_grouped["has_found_banner"]==False) ].index)
    tracker_first_w = len(this_grouped[ (this_grouped["trackers_first"].apply(lambda s: len(s) > 0 )) & ( this_grouped["has_found_banner"]==True) ].index)
    tracker_click_w = len(this_grouped[ (this_grouped["trackers_click"].apply(lambda s: len(s) > 0 )) &( this_grouped["has_found_banner"]==True) ].index)
    plot_data.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR +  " (w/o Banner)": tracker_click_wo/tot_wo*100, # Use the "Click" visits, to take into account all 
                      BEFORE_STR + " (w/ Banner)": tracker_first_w/tot_w*100,
                      AFTER_STR +  " (w/ Banner)": tracker_click_w/tot_w*100,
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="country")
plot_df.index = plot_df["country"]
del plot_df["country"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)
    
plot = fastplot.plot( plot_df ,None, 
               mode='bars_multi', ylabel = 'Websites With Trackers [\\%]',
               legend = True, legend_loc='upper left', legend_ncol=2, legend_fontsize="small", legend_alpha = 0.5,
               grid_axis="y",
               ylim = (0,120), **THIS_PLOT_ARGS)


for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch(r'|\|\|\|\\')
    p.set_edgecolor ("indianred")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch(r'-\-\-\-\\')
    p.set_edgecolor ("darkred")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")

plot.subplots_adjust(left=0.125, bottom=0.1, right=0.95, top=0.85) 

# err = plot_df.applymap(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
err = plot_df.map(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*2500/100,2500,0.05) ]  )
for i, tup in enumerate(err.itertuples()):
    plot.gca().plot( (i-0.2,i-0.2), (tup[1]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (tup[2]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (tup[3]), linestyle="-", color="black" )

plot.savefig("plots/cookieaccept_websites_with_trackers_separate.pdf", bbox_inches = "tight")
plot.show()

# %%
plot_data = []
plot_data_error = []
for country in similarweb_websites.keys():
    this_grouped = grouped[grouped[country] == True]
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len).mean()
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len).mean()
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len).mean()
    
    plot_data.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR: tracker_first,
                      AFTER_STR: tracker_click,
                      ADDITIONAL_STR: tracker_internal,
                     })
    
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len)
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len)
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len)
      
    plot_data_error.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR: (round(np.mean(tracker_first) - 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2),
                                   round(np.mean(tracker_first) + 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2)),
                      AFTER_STR: (round(np.mean(tracker_click) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2),
                                   round(np.mean(tracker_click) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2)),
                      ADDITIONAL_STR: (round(np.mean(tracker_internal) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2),
                                   round(np.mean(tracker_internal) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2)),
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="country")
plot_df.index = plot_df["country"]
del plot_df["country"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)


plot = fastplot.plot( plot_df [[BEFORE_STR, AFTER_STR, ADDITIONAL_STR] ]  ,None, 
               mode='bars_multi', ylabel = 'Average Trackers Per Website',
               legend = True, legend_loc='upper left', legend_ncol=3, legend_fontsize=9,
               grid_axis="y", yticks=(np.arange(0,21,2) ,None),
               ylim = (0,21), **THIS_PLOT_ARGS)

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")
    
#plot.gca().patches[5].set_hatch("XXXX")
#plot.gca().patches[11].set_hatch("++++")
#plot.gca().patches[17].set_hatch("....")

for i, tup in enumerate(plot_df.itertuples()):
    #print(i, tup.Index)
    this_d = None
    for d in plot_data_error:
        if d["country"] == tup.Index:
            this_d = d
    #print (tup.Index, this_d)
    plot.gca().plot( (i-0.2,i-0.2), (this_d[BEFORE_STR]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (this_d[AFTER_STR]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (this_d[ADDITIONAL_STR]), linestyle="-", color="black" )
    
plot.savefig("plots/cookieaccept_trackers_per_website.pdf")
plot.show()

# %%
plot_data = []
plot_data_error = []

for country in similarweb_websites.keys():
    this_grouped = grouped[grouped[country] == True]
    tracker_first_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_first"].apply(len).mean()
    tracker_click_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_click"].apply(len).mean()
    tracker_first_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_first"].apply(len).mean()
    tracker_click_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_click"].apply(len).mean()
     
    plot_data.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR +  " (w/o Banner)": tracker_click_wo, # Use the "Click" visits, to take into account all 
                      BEFORE_STR + " (w/ Banner)": tracker_first_w,
                      AFTER_STR +  " (w/ Banner)": tracker_click_w,
                     })

    tracker_first_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_first"].apply(len)
    tracker_click_wo = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==False)]["trackers_click"].apply(len)
    tracker_first_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_first"].apply(len)
    tracker_click_w = this_grouped[(this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 )) & ( this_grouped["has_found_banner"]==True)]["trackers_click"].apply(len)
     
    plot_data_error.append({"country": COUNTRY_TRAD[country],
                      BEFORE_STR +  " (w/o Banner)": (round(np.mean(tracker_click_wo) - 1.95*np.std(tracker_click_wo)/np.sqrt(len(tracker_click_wo)),2),
                                   round(np.mean(tracker_click_wo) + 1.95*np.std(tracker_click_wo)/np.sqrt(len(tracker_click_wo)),2)),
                      BEFORE_STR + " (w/ Banner)": (round(np.mean(tracker_first_w) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_first_w)),2),
                                   round(np.mean(tracker_first_w) + 1.95*np.std(tracker_first_w)/np.sqrt(len(tracker_first_w)),2)),
                      AFTER_STR +  " (w/ Banner)": (round(np.mean(tracker_click_w) - 1.95*np.std(tracker_click_w)/np.sqrt(len(tracker_click_w)),2),
                                   round(np.mean(tracker_click_w) + 1.95*np.std(tracker_click_w)/np.sqrt(len(tracker_click_w)),2)),
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by="country")
plot_df.index = plot_df["country"]
del plot_df["country"]

THIS_PLOT_ARGS = PLOT_ARGS.copy()
THIS_PLOT_ARGS["figsize"] = (4.25,2.25)

plot = fastplot.plot( plot_df [[BEFORE_STR +  " (w/o Banner)", BEFORE_STR + " (w/ Banner)", AFTER_STR +  " (w/ Banner)"] ]  ,None, 
               mode='bars_multi', ylabel = 'Average Trackers Per Website',
               legend = True, legend_loc='upper left', legend_ncol=2, legend_fontsize=8.75, legend_alpha = 1,
               grid_axis="y", yticks=(np.arange(0,21,2) ,None),
               ylim = (0,21), **THIS_PLOT_ARGS)

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch(r'|\|\|\|\\')
    p.set_edgecolor ("indianred")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch(r'-\-\-\-\\')
    p.set_edgecolor ("darkred")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")
    

for i, tup in enumerate(plot_df.itertuples()):
    #print(i, tup.Index)
    this_d = None
    for d in plot_data_error:
        if d["country"] == tup.Index:
            this_d = d
    #print (tup.Index, this_d)
    plot.gca().plot( (i-0.2,i-0.2), (this_d[BEFORE_STR +  " (w/o Banner)"]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (this_d[BEFORE_STR +  " (w/ Banner)"]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (this_d[AFTER_STR +  " (w/ Banner)"]), linestyle="-", color="black" )
    
# plot.savefig("../plots/cookieaccept_trackers_per_website_separate.pdf")
plot.savefig("plots/cookieaccept_trackers_per_website_separate.pdf")
plot.show()

# %%
tracker_first = Counter()
tracker_click = Counter()
tot = len(this_grouped.index)

for row in this_grouped.itertuples():
    for t in row.trackers_first:
        tracker_first[t] +=1
    for t in row.trackers_click:
        tracker_click[t] +=1        

plot_data = []
for t in tracker_first:
    plot_data.append({
        "tracker": t,
        BEFORE_STR: tracker_first[t]/tot*100,
        AFTER_STR: tracker_click[t]/tot*100,
    })
    
plot_df = pd.DataFrame(plot_data)
plot_df = plot_df.sort_values(by = BEFORE_STR, ascending=False)


plot_list = [(BEFORE_STR,   (np.arange(len(plot_df[BEFORE_STR].values ) ) +1 ,   plot_df[BEFORE_STR].values  ) ),
             (AFTER_STR, (np.arange(len(plot_df[AFTER_STR].values) ) +1 , plot_df[AFTER_STR].values ) ),
            ]

plot = fastplot.plot( plot_list ,None, 
               mode='line_multi', ylabel = 'Pervasiveness [\\%]',
               legend = True, legend_loc='lower left', legend_ncol=1,
               yscale = "log", xscale = "log", xlabel = "Tracker Rank",
               xlim = (0.85, None), cycler = CYCLER_LINESPOINTS, plot_args = {"markersize": 4, "markevery": slice(0, 10, 1)},
               ylim = (0.01,100), **PLOT_ARGS)

plot.savefig("plots/cookieaccept_tracker_pervasiveness_log.pdf")
plot.show()

print("Trackers on >= 1% of websites: {} -> {}".format( len([e for e in plot_list[0][1][1] if e > 1 ]), len([e for e in plot_list[1][1][1] if e >1 ]) ))
# Out:
# Trackers on >= 1% of websites: 84 -> 105

# %%
plot_data = []

for category in categories.keys():
    this_grouped = grouped[grouped[category] == True]
    this_grouped = this_grouped [ this_grouped[["it", "es", "fr", "de", "uk"]].any(axis=1) ] 
    tot = len(this_grouped.index)
    tracker_first = len(this_grouped[this_grouped["trackers_first"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_click = len(this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) > 0 ) ].index)
    tracker_internal = len(this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) > 0 ) ].index)
    if tot>0:
        plot_data.append({"category": category,
                          BEFORE_STR: tracker_first/tot*100,
                          AFTER_STR: tracker_click/tot*100,
                          ADDITIONAL_STR: tracker_internal/tot*100,
                         })
    else:
        print ("    Empty")
    
plot_df = pd.DataFrame(plot_data)
plot_df.index = plot_df["category"]

plot_df = plot_df.sort_values(by = BEFORE_STR, ascending=False)
del plot_df["category"]
THIS_PLOT_ARGS_LARGE = {"style":"latex", "grid":True, "figsize":(9,2), "rcParams":{'text.latex.preamble': '\\usepackage{libertine}\n\\usepackage{setspace}'}, "legend_args":{"columnspacing":1, "handlelength":1.5}}

plot = fastplot.plot( plot_df[[BEFORE_STR, AFTER_STR, ADDITIONAL_STR] ] ,None, 
               mode='bars_multi', ylabel = 'Websites\\\\With Trackers [\\%]', xticks_rotate = 30, xticks_fontsize = "small",
               legend = True, legend_loc='upper right', legend_ncol=3, legend_alpha=1.0,
               grid_axis="y", yticks = ([0,25,50,75,100], None),
               ylim = (0,110), **THIS_PLOT_ARGS_LARGE)

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)]+ [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")
    
for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")

for i, category in enumerate(plot_df.index.values):
    this_grouped = grouped[grouped[category] == True]
    n = int(len(this_grouped[this_grouped["has_found_banner"]].index)/len(this_grouped.index)*100)
    plot.text(i, 114, "\\small {}\\%".format(n), ha="center", bbox = dict(boxstyle='square,pad=0', color="white"))
    
plot.text(11, 122, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

plot.subplots_adjust(left=0.125, bottom=0.1, right=0.95, top=0.85) 


# err = plot_df.applymap(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*500/100,500,0.05) ]  )
err = plot_df.map(lambda v: [ e*100 for e in statsmodels.stats.proportion.proportion_confint(v*500/100,500,0.05) ]  )
for i, tup in enumerate(err.itertuples()):
    plot.gca().plot( (i-0.2,i-0.2), (tup[1]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (tup[2]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (tup[3]), linestyle="-", color="black" )
    
plot.savefig("plots/cookieaccept_websites_with_trackers_category.pdf", bbox_inches = "tight")
plot.show()
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_3528\2955132791.py:51: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plot.text(11, 122, "Consent Banner Found and Accepted", ha="center", bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))

# %%
plot_data = []
plot_data_error = []

for category in categories.keys():
    this_grouped = grouped[grouped[category] == True]
    this_grouped = this_grouped [ this_grouped[["it", "es", "fr", "de", "uk"]].any(axis=1) ] 
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len).mean()
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len).mean()
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len).mean()
    
    plot_data.append({"category": category,
                     BEFORE_STR: tracker_first,
                      AFTER_STR: tracker_click,
                      ADDITIONAL_STR: tracker_internal,
                     })
    
    tracker_first = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_first"].apply(len)
    tracker_click = this_grouped[this_grouped["trackers_click"].apply(lambda s: len(s) >= 0 ) ]["trackers_click"].apply(len)
    tracker_internal = this_grouped[this_grouped["trackers_internal"].apply(lambda s: len(s) >= 0 ) ]["trackers_internal"].apply(len)
      
    plot_data_error.append({"category": category,
                      BEFORE_STR: (round(np.mean(tracker_first) - 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2),
                                   round(np.mean(tracker_first) + 1.95*np.std(tracker_first)/np.sqrt(len(tracker_first)),2)),
                      AFTER_STR: (round(np.mean(tracker_click) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2),
                                   round(np.mean(tracker_click) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_click)),2)),
                      ADDITIONAL_STR: (round(np.mean(tracker_internal) - 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2),
                                   round(np.mean(tracker_internal) + 1.95*np.std(tracker_click)/np.sqrt(len(tracker_internal)),2)),
                     })
    
plot_df = pd.DataFrame(plot_data)
plot_df.index = plot_df["category"]
plot_df = plot_df.sort_values(by = BEFORE_STR, ascending=False)

del plot_df["category"]
plot = fastplot.plot( plot_df[[BEFORE_STR, AFTER_STR, ADDITIONAL_STR] ] ,None, 
               mode='bars_multi', ylabel = '\\begin{center}Average Trackers\\\\Per Website\\end{center}', xticks_rotate = 30,  xticks_fontsize = "small",
               legend = True, legend_loc='upper right', legend_ncol=3,
               grid_axis="y",yticks = (np.arange(0,55,5), None),
               ylim = (0,50), **PLOT_ARGS_LARGE)

for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):2*len(plot_df)] + [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")

for p in plot.gca().patches[2*len(plot_df):] + [plot.gca().get_legend().get_patches()[2]]:
    p.set_hatch("----")
    p.set_edgecolor ("green")
    p.set_facecolor ("white")
    

for i, tup in enumerate(plot_df.itertuples()):
    for d in plot_data_error:
        if d["category"] == tup.Index:
            this_d = d
    plot.gca().plot( (i-0.2,i-0.2), (this_d[BEFORE_STR]), linestyle="-", color="black"  )
    plot.gca().plot( (i,i), (this_d[AFTER_STR]), linestyle="-", color="black" )
    plot.gca().plot( (i+0.2,i+0.2), (this_d[ADDITIONAL_STR]), linestyle="-", color="black" )
plot.savefig("plots/cookieaccept_trackers_per_website_category.pdf")
plot.show()
plot_df["Increase"] = plot_df[AFTER_STR] - plot_df[BEFORE_STR]

# %%
df_tmp = df[["sld", "banner_text"]].copy()
df_tmp["banner_text"] = df_tmp["banner_text"].str.lower()
df_tmp = df_tmp.groupby("sld")["banner_text"].apply(lambda l: l.values[0] if len(l)>0 else None)

counts = df_tmp.reset_index().groupby("banner_text").size().sort_values(ascending=False)
missing = 258 - len(counts)
# counts = counts.append( pd.Series( [1]*missing, index = ["-"]*missing ) )
counts = counts._append( pd.Series( [1]*missing, index = ["-"]*missing ) )

counts_cum = df_tmp.reset_index().groupby("banner_text").size().sort_values(ascending=False)
counts_cum = counts_cum.cumsum()/sum(counts_cum)
missing = 258 - len(counts_cum)
# counts_cum = counts_cum.append( pd.Series( [1]*missing, index = ["-"]*missing ) )
counts_cum = counts_cum._append( pd.Series( [1]*missing, index = ["-"]*missing ) )

percs = [0.5,0.75,0.9,0.95,0.99]
vals = [None]*len(percs)
for i, v in enumerate(counts_cum.values):
    for j in np.arange(len(vals)):
        if vals[j] == None and v>percs[j]:
            vals[j] = i

plot = fastplot.plot( (np.arange(len(counts)) +1, counts) ,None, 
               mode='line', xlabel = 'Keyword Rank', ylabel = "Frequency",
               legend = False, legend_loc='upper left', legend_ncol=3,
               xlim=(-5,260), xticks = ([1,50,100,150,200,250],None),
               yticks = ([1,2,5,10,20,50,100,200,500,1000],[1,2,5,10,20,50,100,200,500,1000]),
               plot_args = dict(drawstyle='steps-pre', markersize= 6, markevery = vals),
               yscale = "log", 
                     cycler = CYCLER_LINESPOINTS,
               ylim = (0.7,None), **PLOT_ARGS)

for i, v in enumerate(vals):
    plot.text (v, np.power(10,np.log10(counts[v]*2.5)), f"Coverage={int(percs[i]*100)}\\%", rotation = 0, ha="left", va="top", \
                   bbox = dict(boxstyle='square,pad=0', facecolor='white', color="white"))
#plot.plot([1,1], [0,counts[0]], "-", color ="red")
plot.savefig("plots/cookieaccept_keywords_freq_abs_alt.pdf")
plot.show()
# Out:
# C:\Users\zhang\AppData\Local\Temp\ipykernel_3528\615299093.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plot.text (v, np.power(10,np.log10(counts[v]*2.5)), f"Coverage={int(percs[i]*100)}\\%", rotation = 0, ha="left", va="top", \
# C:\Users\zhang\AppData\Local\Temp\ipykernel_3528\615299093.py:34: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plot.text (v, np.power(10,np.log10(counts[v]*2.5)), f"Coverage={int(percs[i]*100)}\\%", rotation = 0, ha="left", va="top", \

# %%
plot_data = []
consen_o_matic_found_random = set( [ getGood2LD(l) for l in open("random-eu-found-consent-o-matic.txt", "r").read().splitlines() ])
random_websites = set( [ getGood2LD(l) for l in open("random-eu.txt", "r").read().splitlines() ])

for country in ["fr", "de", "it", "es", "uk"]:
    this_grouped = grouped[grouped[country] == True]
    this_list = this_grouped[["sld", "has_found_banner"]]
    this_list = this_list[this_list["sld"].isin(random_websites)]
    this_list["consent_o_matic_found"] = this_list["sld"].isin(consen_o_matic_found_random)
    
    tot = len(this_list.index)
    has_found_banner = len(this_list[this_list["has_found_banner"]==True ].index)
    consen_o_matic_found_nb = len(this_list[this_list["consent_o_matic_found"]==True ].index)
    plot_data.append({"country": COUNTRY_TRAD[country],
                      "Cookie-Accept": has_found_banner/tot*100,
                      "Consent-O-Matic": consen_o_matic_found_nb/tot*100,
                     })
    

plot_df = pd.DataFrame(plot_data).set_index("country")
plot = fastplot.plot( plot_df, None, 
               mode='bars_multi', ylabel = '\\begin{center}Consent Banner Found\\\\and Accepted [\\%]\\end{center}',
               legend = True, legend_loc='upper left', legend_ncol=2,
               grid_axis="y", yticks = ([0,25,50,75,100],None),
               ylim = (0,100), **PLOT_ARGS)


for p in plot.gca().patches[:len(plot_df)] + [plot.gca().get_legend().get_patches()[0]]:
    p.set_hatch("\\\\\\\\\\")
    p.set_edgecolor ("blue")
    p.set_facecolor ("white")
for p in plot.gca().patches[len(plot_df):]+ [plot.gca().get_legend().get_patches()[1]]:
    p.set_hatch("/////")
    p.set_edgecolor ("red")
    p.set_facecolor ("white")

plot.savefig("plots/cookieaccept_consentomatic_random.pdf")
plot.show()

# %%
avgs = []
with_trackers = []

for i in range(5): 
    vals = grouped[  grouped["trackers_incremental_nb"].apply(len)>=5 ] ["trackers_incremental_nb"].apply(lambda l: l[i])
    avgs.append(np.mean(vals.values))
    with_trackers.append( len([ v for v in vals.values if  v> 0])   /len(vals.values)*100 )
    
def mycallbak(plt):
    ax1 = plt.gca()
    ax2 = plt.gca().twinx()
    
    ax1.set_xlabel("Visits")
    ax1.plot(np.arange(5)+1, avgs, color="red", marker="o")
    ax1.set_ylabel("\\begin{center}Average Trackers\\\\Per Website\\end{center}")
    ax1.yaxis.label.set_color('red')
    ax1.set_ylim(5,10)
    
    ax2.plot(np.arange(5)+1, with_trackers, color="blue", marker="<")
    ax2.set_ylim(69,71)
    ax2.set_ylabel('Websites\\\\With Trackers [\\%]')
    ax2.yaxis.label.set_color('blue')
    

plot = fastplot.plot(None, None, mode="callback", callback=mycallbak,
                     xlim=(0.8, 5.2), xticks = ([1,2,3,4,5], None),
                     **PLOT_ARGS)
plot.savefig("plots/cookieaccept_visits_nb.pdf")
plot.show()
